# %%
a = 10
a
# Out:
# 10

# %%
s = 'zxcvbnm,'
s[0]
# Out:
# 'z'

# %%
s[1:3]
# Out:
# 'xc'

# %%
len(s)
# Out:
# 8

# %%
s + s
# Out:
# 'zxcvbnm,zxcvbnm,'

# %%
s*3
# Out:
# 'zxcvbnm,zxcvbnm,zxcvbnm,'

# %%
s.capitalize()
# Out:
# 'Zxcvbnm,'

# %%
s = s.capitalize()
s
# Out:
# 'Zxcvbnm,'

# %%
s.count('a')
# Out:
# 0

# %%
s.split('c')
# Out:
# ['Zx', 'vbnm,']

# %%
new_list = [1, 2, 3, 'Sasha', 'Olya', 'qwrty']

# %%
len(new_list)
# Out:
# 6

# %%
type(new_list)
# Out:
# list

# %%
new_list * 2
# Out:
# [1, 2, 3, 'Sasha', 'Olya', 'qwrty', 1, 2, 3, 'Sasha', 'Olya', 'qwrty']

# %%
new_list + new_list
# Out:
# [1, 2, 3, 'Sasha', 'Olya', 'qwrty', 1, 2, 3, 'Sasha', 'Olya', 'qwrty']

# %%
new_list[3] = new_list[3].lower()
new_list
# Out:
# [1, 2, 3, 'sasha', 'Olya', 'qwrty']

# %%
new_list[-1]
# Out:
# 'qwrty'

# %%
students = ['Sasha', 'Olya', 'Ihor', 'Katya']
students
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya']

# %%
students.append('Marina')
students
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya', 'Marina']

# %%
python = ['Nataliia', 'Vitalii']
students.append(python)
students
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya', 'Marina', ['Nataliia', 'Vitalii']]

# %%
del students[-1]
students
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya', 'Marina']

# %%
students.extend(python)
students
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya', 'Marina', 'Nataliia', 'Vitalii']

# %%
students + python
# Out:
# ['Sasha',
#  'Olya',
#  'Ihor',
#  'Katya',
#  'Marina',
#  'Nataliia',
#  'Vitalii',
#  'Nataliia',
#  'Vitalii']

# %%
#students += python
#students = students + python

# %%
students.count('Sasha')
# Out:
# 1

# %%
students.pop()
students
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya', 'Marina', 'Nataliia']

# %%
students.reverse()
students
# Out:
# ['Nataliia', 'Marina', 'Katya', 'Ihor', 'Olya', 'Sasha']

# %%
list(reversed(students))
# Out:
# ['Sasha', 'Olya', 'Ihor', 'Katya', 'Marina', 'Nataliia']

# %%
students
# Out:
# ['Nataliia', 'Marina', 'Katya', 'Ihor', 'Olya', 'Sasha']

# %%
a = [3, 1, 10, -5]
a.sort(reverse=True)
a
# Out:
# [10, 3, 1, -5]

# %%
help(a.sort)
# Out:
# Help on built-in function sort:
#
# sort(*, key=None, reverse=False) method of builtins.list instance
#     Sort the list in ascending order and return None.
#
#     The sort is in-place (i.e. the list itself is modified) and stable (i.e. the
#     order of two equal elements is maintained).
#
#     If a key function is given, apply it once to each list item and sort them,
#     ascending or descending, according to their function values.
#
#     The reverse flag can be set to sort in descending order.

# %%
sorted(a, reverse=True)
# Out:
# [10, 3, 1, -5]

# %%
sorted(students)
# Out:
# ['Ihor', 'Katya', 'Marina', 'Nataliia', 'Olya', 'Sasha']

# %%
'Ihor' > 'Iatya'
# Out:
# True

# %%
sorted(students + a)
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
# TypeError: '<' not supported between instances of 'int' and 'str'

# %%
sorted(['1', 'a', 'z', 'A'])
# Out:
# ['1', 'A', 'a', 'z']

# %%
'a' > 'A'
# Out:
# True

# %%
'Sasha' in students
# Out:
# True

# %%
students = tuple(students)
students
# Out:
# ('Nataliia', 'Marina', 'Katya', 'Ihor', 'Olya', 'Sasha')

# %%
students[0] = 'Taras'
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
# TypeError: 'tuple' object does not support item assignment

# %%
dict_with_students = {
    'Sasha': 0, 
    'Olya': 0, 
    'Ihor': 0
}

# %%
dict_with_students
# Out:
# {'Sasha': 0, 'Olya': 0, 'Ihor': 0}

# %%
len(dict_with_students)
# Out:
# 3

# %%
dict_with_students['Sasha'] = 3

# %%
dict_with_students
# Out:
# {'Sasha': 3, 'Olya': 0, 'Ihor': 0}

# %%
dict_with_students.keys()
# Out:
# dict_keys(['Sasha', 'Olya', 'Ihor'])

# %%
list(dict_with_students.values())
# Out:
# [3, 0, 0]

# %%
list(dict_with_students.items())[0][1]
# Out:
# 0

# %%
#dict_with_students = 10

# %%
dict_with_students.get('Alex', 0)
# Out:
# 0

# %%
dict_with_students['Alex']
# Out:
# ---------------------------------------------------------------------------
# Traceback (most recent call last)
#     at line 1 in <module>
# KeyError: 'Alex'

# %%
python = {'Sasha', 'Olya', 'Ihor'}
ds = {'Nataliia', 'Marina', 'Katya', 'Ihor'}

# %%
python
# Out:
# {'Ihor', 'Olya', 'Sasha'}

# %%
python | ds
# Out:
# {'Ihor', 'Katya', 'Marina', 'Nataliia', 'Olya', 'Sasha'}

# %%
python & ds
# Out:
# {'Ihor'}

# %%
python - ds
# Out:
# {'Olya', 'Sasha'}

# %%
python.add('qer')
python
# Out:
# {'Ihor', 'Olya', 'Sasha', 'qer'}

# %%
a = None
a

# %% [markdown]
# - int
# - float
# - bool
# - complex
# - str
# - list
# - tuple
# - dict
# - set
# - None

# %%
#bla lavka 
student_age = 15 

if student_age < 18:
    print('BLOCK')
else:
    print('Save')
# Out:
# BLOCK
